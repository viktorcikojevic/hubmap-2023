# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load training_log.csv to a pandas dataframe
df = pd.read_csv('segformer.csv')
df
# Out:
#     epoch  loss_train  loss_val  th_best  best_fbeta
# 0       1    1.295189  1.271964     0.80    0.097193
# 1       2    1.061633  0.932523     0.61    0.114053
# 2       3    0.810067  0.732962     0.54    0.128178
# 3       4    0.707712  0.685982     0.50    0.129605
# 4       5    0.624524  0.626846     0.43    0.125788
# ..    ...         ...       ...      ...         ...
# 90     91    0.030571  0.079596     0.38    0.729640
# 91     92    0.030576  0.077229     0.41    0.731202
# 92     93    0.030874  0.084917     0.33    0.711737
# 93     94    0.031235  0.093345     0.37    0.702675
# 94     95    0.029745  0.079003     0.39    0.730884
#
# [95 rows x 5 columns]

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['loss_train'], label='loss_train')
plt.plot(df['epoch'], df['loss_val'], label='loss_val')
plt.legend()

# plt.ylim(0., 0.2)

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['best_fbeta'], label='best_fbeta')

plt.ylim(0.6, 0.9)
# Out:
# (0.6, 0.9)

# %%
# print row with best fbeta
df.iloc[df['best_fbeta'].idxmax()]
# Out:
# epoch         40.000000
# loss_train     0.053448
# loss_val       0.061807
# th_best        0.380000
# best_fbeta     0.734837
# Name: 39, dtype: float64
