# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load training_log.csv to a pandas dataframe
df = pd.read_csv('segformer.csv')
df
# Out:
#     epoch  loss_train  loss_val   th_best  best_fbeta
# 0       1    0.382503  0.371578  0.534667    0.100244
# 1       2    0.321082  0.259617  0.316667    0.109775
# 2       3    0.231693  0.209284  0.134667    0.100022
# 3       4    0.207243  0.200997  0.090000    0.106850
# 4       5    0.198158  0.193898  0.056333    0.099501
# 5       6    0.197599  0.188710  0.050000    0.108201
# 6       7    0.187339  0.184349  0.050000    0.055247
# 7       8    0.187613  0.182563  0.050000    0.048237
# 8       9    0.185105  0.179930  0.050000    0.031471
# 9      10    0.181388  0.180986  0.050000    0.031543
# 10     11    0.180443  0.179224  0.081333    0.014530
# 11     12    0.179059  0.178420  0.165000    0.013342
# 12     13    0.178263  0.177817  0.196333    0.012714
# 13     14    0.177702  0.177398  0.181000    0.012159
# 14     15    0.177296  0.176911  0.160667    0.011688
# 15     16    0.176847  0.176633  0.149000    0.010360
# 16     17    0.175780  0.175107  0.080000    0.000000
# 17     18    0.174945  0.174716  0.080000    0.000000
# 18     19    0.174644  0.174501  0.080000    0.000000
# 19     20    0.174431  0.174298  0.080000    0.000000
# 20     21    0.174265  0.174164  0.080000    0.000000

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['loss_train'], label='loss')
plt.plot(df['epoch'], df['loss_val'], label='val_loss')
plt.legend()

plt.ylim(0.15, 0.2)
# Out:
# (0.15, 0.2)
