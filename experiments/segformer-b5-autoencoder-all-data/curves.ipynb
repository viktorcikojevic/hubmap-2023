# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load training_log.csv to a pandas dataframe
df = pd.read_csv('segformer.csv')
df
# Out:
#     epoch  loss_train  loss_val
# 0       1    0.057326  0.019025
# 1       2    0.020874  0.009510
# 2       3    0.012656  0.008868
# 3       4    0.009906  0.008598
# 4       5    0.009164  0.008226
# ..    ...         ...       ...
# 60     61    0.005248  0.003775
# 61     62    0.005241  0.003781
# 62     63    0.005210  0.003743
# 63     64    0.005203  0.003716
# 64     65    0.005176  0.003716
#
# [65 rows x 3 columns]

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['loss_train'], label='loss_train')
plt.plot(df['epoch'], df['loss_val'], label='loss_val')
plt.legend()

# plt.ylim(0.038, 0.04)

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], np.sqrt(df['loss_train'])/0.1, label='loss_train')
plt.plot(df['epoch'], np.sqrt(df['loss_val'])/0.1, label='loss_val')
plt.legend()

plt.ylim(0.5, 1.2)
# Out:
# (0.5, 1.2)

# %%
# # Plot loss and val_loss vs epoch
# plt.figure(figsize=(10, 6))

# plt.plot(df['epoch'], df['best_fbeta'], label='best_fbeta')

# # plt.ylim(0.15, 0.2)
