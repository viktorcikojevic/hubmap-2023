# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load training_log.csv to a pandas dataframe
df = pd.read_csv('segformer.csv')
df
# Out:
#     epoch  loss_train  loss_val  th_best  best_fbeta
# 0       1    0.611250  0.580598     0.50    0.102321
# 1       2    0.461909  0.303521     0.33    0.172862
# 2       3    0.275935  0.204555     0.40    0.347854
# 3       4    0.189774  0.147811     0.30    0.492809
# 4       5    0.147751  0.128062     0.40    0.571743
# ..    ...         ...       ...      ...         ...
# 95     96    0.008659  0.133051     0.26    0.704848
# 96     97    0.008473  0.132702     0.28    0.704959
# 97     98    0.008236  0.138109     0.22    0.705388
# 98     99    0.008081  0.136230     0.32    0.706816
# 99    100    0.008037  0.142110     0.21    0.706707
#
# [100 rows x 5 columns]

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['loss_train'], label='loss_train')
plt.plot(df['epoch'], df['loss_val'], label='loss_val')
plt.legend()

plt.ylim(0., 0.2)
# Out:
# (0.0, 0.2)

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['best_fbeta'], label='best_fbeta')

plt.ylim(0.6, 0.75)
# Out:
# (0.6, 0.75)

# %%
# print row with best fbeta
df.iloc[df['best_fbeta'].idxmax()]
# Out:
# epoch         99.000000
# loss_train     0.008081
# loss_val       0.136230
# th_best        0.320000
# best_fbeta     0.706816
# Name: 98, dtype: float64
