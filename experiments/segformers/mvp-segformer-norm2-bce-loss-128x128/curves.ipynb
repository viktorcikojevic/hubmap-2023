# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load training_log.csv to a pandas dataframe
df = pd.read_csv('segformer.csv')
df
# Out:
#      epoch  loss_train  loss_val  th_best  best_fbeta
# 0        1    0.846124  0.808350     0.53    0.077366
# 1        2    0.804450  0.721903     0.53    0.105230
# 2        3    0.696000  0.592526     0.53    0.096098
# 3        4    0.551766  0.443158     0.27    0.109542
# 4        5    0.421136  0.347249     0.26    0.096874
# ..     ...         ...       ...      ...         ...
# 442    443    0.056143  0.073641     0.30    0.704404
# 443    444    0.055791  0.078800     0.41    0.647754
# 444    445    0.061165  0.072614     0.37    0.699921
# 445    446    0.053783  0.055689     0.45    0.670593
# 446    447    0.050688  0.067088     0.43    0.733981
#
# [447 rows x 5 columns]

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['loss_train'], label='loss_train')
plt.plot(df['epoch'], df['loss_val'], label='loss_val')
plt.legend()

plt.ylim(0., 0.2)
# Out:
# (0.0, 0.2)

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))
1
plt.plot(df['epoch'], df['best_fbeta'], label='best_fbeta')

plt.ylim(0.2, 0.8)
# Out:
# (0.2, 0.8)

# %%
# print row with best fbeta
df.iloc[df['best_fbeta'].idxmax()]
# Out:
# epoch         392.000000
# loss_train      0.057678
# loss_val        0.064746
# th_best         0.350000
# best_fbeta      0.801209
# Name: 391, dtype: float64
