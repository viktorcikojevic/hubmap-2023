# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load training_log.csv to a pandas dataframe
df = pd.read_csv('segformer.csv')
df
# Out:
#      epoch  loss_train  loss_val  th_best  best_fbeta
# 0        1    1.006748  0.986389     0.67    0.107195
# 1        2    0.986321  0.908994     0.68    0.104025
# 2        3    0.936733  0.831723     0.63    0.120070
# 3        4    0.846385  0.726841     0.62    0.111948
# 4        5    0.693156  0.563152     0.39    0.097472
# ..     ...         ...       ...      ...         ...
# 282    283    0.037779  0.070241     0.35    0.741945
# 283    284    0.041243  0.058944     0.42    0.741717
# 284    285    0.038435  0.060116     0.56    0.709991
# 285    286    0.038930  0.071004     0.40    0.726132
# 286    287    0.044963  0.066209     0.44    0.698656
#
# [287 rows x 5 columns]

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['loss_train'], label='loss_train')
plt.plot(df['epoch'], df['loss_val'], label='loss_val')
plt.legend()

# plt.ylim(0., 0.2)

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))
1
plt.plot(df['epoch'], df['best_fbeta'], label='best_fbeta')

# plt.ylim(0.2, 0.8)

# %%
# print row with best fbeta
df.iloc[df['best_fbeta'].idxmax()]
# Out:
# epoch         228.000000
# loss_train      0.045168
# loss_val        0.061592
# th_best         0.340000
# best_fbeta      0.761801
# Name: 227, dtype: float64
