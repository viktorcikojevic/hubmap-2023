# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load training_log.csv to a pandas dataframe
df = pd.read_csv('segformer.csv')
df
# Out:
#     epoch  loss_train  loss_val  th_best  best_fbeta
# 0       1    0.724723  0.720478     0.47    0.116071
# 1       2    0.680316  0.624787     0.53    0.298744
# 2       3    0.572913  0.487096     0.67    0.525970
# 3       4    0.471229  0.403272     0.74    0.573653
# 4       5    0.401134  0.352522     0.61    0.596269
# ..    ...         ...       ...      ...         ...
# 95     96    0.106033  0.194670     0.65    0.737602
# 96     97    0.105783  0.190083     0.55    0.740349
# 97     98    0.105255  0.190791     0.25    0.739906
# 98     99    0.103127  0.199135     0.53    0.731065
# 99    100    0.104900  0.194912     0.50    0.736315
#
# [100 rows x 5 columns]

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['loss_train'], label='loss_train')
plt.plot(df['epoch'], df['loss_val'], label='loss_val')
plt.legend()

# plt.ylim(0.15, 0.2)

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))
1
plt.plot(df['epoch'], df['best_fbeta'], label='best_fbeta')

plt.ylim(0.7, 0.75)
# Out:
# (0.7, 0.75)

# %%
# print row with best fbeta
df.iloc[df['best_fbeta'].idxmax()]
# Out:
# epoch         74.000000
# loss_train     0.124933
# loss_val       0.181409
# th_best        0.370000
# best_fbeta     0.748258
# Name: 73, dtype: float64
