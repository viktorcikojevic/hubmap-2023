# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load training_log.csv to a pandas dataframe
df = pd.read_csv('segformer.csv')
df
# Out:
#     epoch  loss_train  loss_val  th_best  best_fbeta
# 0       1    0.771606  0.758722     0.48    0.100460
# 1       2    0.710499  0.644602     0.45    0.185379
# 2       3    0.605209  0.545540     0.66    0.443357
# 3       4    0.509072  0.439956     0.56    0.563552
# 4       5    0.440693  0.375491     0.57    0.596302
# ..    ...         ...       ...      ...         ...
# 95     96    0.108587  0.190580     0.42    0.738133
# 96     97    0.109907  0.200261     0.30    0.725585
# 97     98    0.121489  0.196765     0.24    0.724373
# 98     99    0.108381  0.203000     0.41    0.718543
# 99    100    0.107013  0.193494     0.19    0.737052
#
# [100 rows x 5 columns]

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['loss_train'], label='loss_train')
plt.plot(df['epoch'], df['loss_val'], label='loss_val')
plt.legend()

plt.ylim(0.1, 0.3)
# Out:
# (0.1, 0.3)

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))
1
plt.plot(df['epoch'], df['best_fbeta'], label='best_fbeta')

plt.ylim(0.65, 0.8)
# Out:
# (0.65, 0.8)

# %%
# print row with best fbeta
df.iloc[df['best_fbeta'].idxmax()]
# Out:
# epoch         95.000000
# loss_train     0.108416
# loss_val       0.188051
# th_best        0.260000
# best_fbeta     0.744274
# Name: 94, dtype: float64
