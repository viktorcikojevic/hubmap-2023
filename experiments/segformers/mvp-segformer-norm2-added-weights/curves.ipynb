# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load training_log.csv to a pandas dataframe
df = pd.read_csv('segformer.csv')
df
# Out:
#     epoch  loss_train  loss_val  th_best  best_fbeta
# 0       1    6.088140  5.434485    0.563    0.106152
# 1       2    3.337933  1.957364    0.936    0.215102
# 2       3    1.768482  1.464076    0.975    0.368821
# 3       4    1.480555  1.266396    0.985    0.458095
# 4       5    1.320357  1.126535    0.985    0.505405
# ..    ...         ...       ...      ...         ...
# 57     58    0.444561  1.492808    0.990    0.694174
# 58     59    0.443697  1.545139    0.987    0.691374
# 59     60    0.424278  1.705654    0.985    0.677248
# 60     61    0.438526  1.193989    0.989    0.667572
# 61     62    0.438177  1.518289    0.987    0.689594
#
# [62 rows x 5 columns]

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['loss_train'], label='loss_train')
plt.plot(df['epoch'], df['loss_val'], label='loss_val')
plt.legend()

# plt.ylim(0.15, 0.2)

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))
1
plt.plot(df['epoch'], df['best_fbeta'], label='best_fbeta')

# plt.ylim(0.7, 0.75)

# %%
# print row with best fbeta
df.iloc[df['best_fbeta'].idxmax()]
# Out:
# epoch         58.000000
# loss_train     0.444561
# loss_val       1.492808
# th_best        0.990000
# best_fbeta     0.694174
# Name: 57, dtype: float64
