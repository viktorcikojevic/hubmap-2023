# %%
import pandas as pd

df = pd.read_csv('runs/segment/train/results.csv')

# remove spaces in column names
df.columns = df.columns.str.replace(' ', '')

df
# Out:
#      epoch  train/box_loss  train/seg_loss  train/cls_loss  train/dfl_loss
# 0        0          2.2667          3.0967         2.16820          1.7692  \
# 1        1          1.7666          2.5538         1.47470          1.3809
# 2        2          1.7546          2.5055         1.43530          1.3298
# 3        3          1.7240          2.4419         1.41260          1.2968
# 4        4          1.6773          2.3880         1.38850          1.2881
# ..     ...             ...             ...             ...             ...
# 165    165          1.3026          1.7359         0.96268          1.0892
# 166    166          1.3084          1.7411         0.97584          1.0763
# 167    167          1.3042          1.7192         0.96097          1.0785
# 168    168          1.2887          1.7352         0.95341          1.0790
# 169    169          1.3149          1.7480         0.96806          1.0831
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)
# ...

# %%
# plot val/box_loss + 	val/seg_loss	+ val/cls_loss vs epoch
import matplotlib.pyplot as plt

plt.plot(df['epoch'], df['val/box_loss'] + df['val/seg_loss'] + df['val/cls_loss'])

# %%
# plot metrics/mAP50(M)	vs epoch
import matplotlib.pyplot as plt

plt.plot(df['epoch'], df['metrics/mAP50(M)'])

# print the maximum mAP50(M) and the epoch it occurs
print(df['metrics/mAP50(M)'].max())
print(df['epoch'][df['metrics/mAP50(M)'].idxmax()])

plt.ylim(0.7)
# Out:
# 0.74251
# 147
# (0.7, 0.7588315)
