# %%
import pandas as pd

path_file = "runs/segment/train6/results.csv"
 
df = pd.read_csv(path_file)
# remove spaces from column names
df.columns = df.columns.str.replace(' ', '')


df
# Out:
#     epoch  train/box_loss  train/seg_loss  train/cls_loss  train/dfl_loss
# 0       0          1.8165          2.3886          1.9049          1.3438  \
# 1       1          1.6588          2.1895          1.6631          1.2657
# 2       2          1.5991          2.0958          1.5608          1.2358
# 3       3          1.5613          2.0175          1.5026          1.2212
# 4       4          1.5444          1.9886          1.4667          1.2134
# ..    ...             ...             ...             ...             ...
# 59     59          1.3615          1.7431          1.0713          1.1301
# 60     60          1.3548          1.7412          1.0738          1.1285
# 61     61          1.3523          1.7386          1.0675          1.1304
# 62     62          1.3489          1.7371          1.0627          1.1303
# 63     63          1.3430          1.7242          1.0511          1.1205
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)
# ...

# %%
# plot "metrics/mAP50(M)"

import matplotlib.pyplot as plt

plt.plot(df["epoch"], df["metrics/mAP50(M)"])

plt.ylim(0.6, 0.75)

# put horizontal line at 0.7
plt.axhline(y=0.7, color='r', linestyle='-')

# %%
# plot "metrics/mAP50(M)"

import matplotlib.pyplot as plt

plt.plot(df["epoch"], df["train/seg_loss"])

# plt.ylim(0.6, 0.75)

# put horizontal line at 0.7
# plt.axhline(y=0.7, color='r', linestyle='-')

# %%
# plot "metrics/mAP50(M)"

import matplotlib.pyplot as plt

plt.plot(df["epoch"], df["val/seg_loss"])

# plt.ylim(0.6, 0.75)

# put horizontal line at 0.7
# plt.axhline(y=0.7, color='r', linestyle='-')

# %%
# plot "metrics/mAP50(M)"

import matplotlib.pyplot as plt

plt.plot(df["epoch"], df["val/cls_loss"])

# plt.ylim(0.6, 0.75)

# put horizontal line at 0.7
# plt.axhline(y=0.7, color='r', linestyle='-')

# %%
import numpy as np

np.argmax(df["metrics/mAP50(M)"]), np.max(df["metrics/mAP50(M)"])
# Out:
# (62, 0.74287)
