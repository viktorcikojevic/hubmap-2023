# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load training_log.csv to a pandas dataframe
df = pd.read_csv('log.csv')
df
# Out:
#      epoch  loss_train  loss_val            lr
# 0        0    0.891470  0.863270  3.000000e-07
# 1        1    0.752584  0.650255  3.270000e-06
# 2        2    0.626954  0.589495  6.240000e-06
# 3        3    0.588116  0.573379  9.210000e-06
# 4        4    0.572810  0.558949  1.218000e-05
# ..     ...         ...       ...           ...
# 148    148    0.399327  0.291309  3.000000e-05
# 149    149    0.393486  0.301476  3.000000e-05
# 150    150    0.400201  0.297789  3.000000e-05
# 151    151    0.406902  0.301018  3.000000e-05
# 152    152    0.412622  0.289340  3.000000e-05
#
# [153 rows x 4 columns]

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['loss_train'], label='loss_train')
plt.plot(df['epoch'], df['loss_val'], label='loss_val')
plt.legend()

plt.ylim(0.2, 0.5)
# Out:
# (0.2, 0.5)

# %%
# print min loss_val and argmin loss_val
print(df['loss_val'].min())
print(df['loss_val'].argmin())
# Out:
# 0.2819464886417755
# 111
