# %%
# load losses.txt to array
import numpy as np
import matplotlib.pyplot as plt

losses = np.loadtxt('losses.txt')
plt.plot(losses)

# plt.ylim(0.5, 1)
print(np.argmax(losses), np.max(losses))
# Out:
# 130 0.669
