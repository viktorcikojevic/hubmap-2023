# %%
# load losses.txt to array
import numpy as np
import matplotlib.pyplot as plt

losses = np.loadtxt('losses.txt')
plt.plot(losses)

plt.ylim(0.5, 0.7)
# plt.xlim(15, 40)
# Out:
# (0.5, 0.7)

# %%
# load losses.txt to array
import numpy as np
import matplotlib.pyplot as plt

losses = np.loadtxt('losses.txt')
plt.plot(losses)

plt.ylim(0.5, 0.7)
plt.xlim(15, 40)
# Out:
# (15.0, 40.0)
