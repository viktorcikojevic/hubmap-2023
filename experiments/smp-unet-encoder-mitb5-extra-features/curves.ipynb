# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load training_log.csv to a pandas dataframe
df = pd.read_csv('segformer.csv')
df
# Out:
#      epoch  loss_train  mask_loss_train  boundaries_loss_train
# 0        1    2.056582         0.709843               0.604408  \
# 1        2    1.335975         0.674524               0.559117
# 2        3    1.131255         0.586567               0.477420
# 3        4    0.935519         0.484042               0.392053
# 4        5    0.743021         0.385837               0.307212
# ..     ...         ...              ...                    ...
# 149    150    0.085526         0.052609               0.015966
# 150    151    0.084393         0.051893               0.015859
# 151    152    0.088640         0.054684               0.015830
# 152    153    0.086186         0.052818               0.015893
# 153    154    0.086866         0.053338               0.015970
#
#      dist_loss_train  loss_val  th_best  best_fbeta  mask_loss_val
# 0           0.742331  1.670337     0.50    0.094441       0.692847  \
# 1           0.102334  1.220628     0.48    0.100011       0.632539
# 2           0.067268  1.016425     0.41    0.095590       0.539232
# 3           0.059423  0.859001     0.42    0.303788       0.451249
# 4           0.049972  0.629898     0.37    0.462048       0.335646
# ..               ...       ...      ...         ...            ...
# 149         0.016950  0.094876     0.37    0.728382       0.059277
# 150         0.016640  0.108128     0.38    0.700105       0.066549
# 151         0.018126  0.092314     0.35    0.734178       0.057828
# 152         0.017475  0.140125     0.38    0.645272       0.079011
# 153         0.017558  0.098291     0.29    0.721500       0.061895
#
#      boundaries_loss_val  dist_loss_val
# 0               0.614753       0.362737
# 1               0.525823       0.062267
# 2               0.422111       0.055082
# 3               0.359221       0.048532
# 4               0.258884       0.035368
# ..                   ...            ...
# 149             0.015497       0.020102
# 150             0.015509       0.026070
# 151             0.015480       0.019006
# 152             0.015739       0.045374
# 153             0.015765       0.020631
#
# [154 rows x 11 columns]

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['loss_train'], label='loss_train')
plt.plot(df['epoch'], df['loss_val'], label='loss_val')
plt.legend()

plt.ylim(0., 0.2)
# Out:
# (0.0, 0.2)

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['mask_loss_train'], label='mask_loss_train')
plt.plot(df['epoch'], df['mask_loss_val'], label='mask_loss_val')
plt.legend()

plt.ylim(0., 0.2)
# Out:
# (0.0, 0.2)

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['boundaries_loss_train'], label='boundaries_loss_train')
plt.plot(df['epoch'], df['boundaries_loss_val'], label='boundaries_loss_val')
plt.legend()

plt.ylim(0., 0.05)
# Out:
# (0.0, 0.05)

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['dist_loss_train'], label='dist_loss_train')
plt.plot(df['epoch'], df['dist_loss_val'], label='dist_loss_val')
plt.legend()

plt.ylim(0., 0.05)
# Out:
# (0.0, 0.05)

# %%
# Plot loss and val_loss vs epoch
plt.figure(figsize=(10, 6))
1
plt.plot(df['epoch'], df['best_fbeta'], label='best_fbeta')

plt.ylim(0.6, 0.75)
# Out:
# (0.6, 0.75)

# %%
# print row with best fbeta
df.iloc[df['best_fbeta'].idxmax()]
# Out:
# epoch                    118.000000
# loss_train                 0.090247
# mask_loss_train            0.055877
# boundaries_loss_train      0.016079
# dist_loss_train            0.018291
# loss_val                   0.089570
# th_best                    0.400000
# best_fbeta                 0.747220
# mask_loss_val              0.056447
# boundaries_loss_val        0.015517
# dist_loss_val              0.017606
# Name: 117, dtype: float64
